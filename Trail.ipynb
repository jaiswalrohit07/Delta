# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# !pip install plotly
# import plotly as pt

# %%
df = pd.read_csv('bitcoin_ohlc_1000vol2.csv')

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#    index closing_timestamp     open     high      low    close       volume  \
# 0      1     18/08/17 2:42  4261.48  4485.39  4134.61  4252.95  1000.481769
# 1      2     19/08/17 0:06  4252.95  4371.52  3938.77  4104.36  1000.687818
# 2      3     21/08/17 2:43  4121.81  4211.08  3850.00  4067.11  1000.229140
# 3      4    22/08/17 11:06  4050.98  4104.68  3400.00  3864.48  1002.476402
# 4      5    23/08/17 13:03  3864.48  4265.80  3786.81  4216.00  1001.566310
#
#        netvol      buyvol     sellvol  price change  regression_10period  \
# 0  543.691217  772.086493  228.395276           NaN                  NaN
# 1  643.721168  822.204493  178.483325       -148.59                  NaN
# 2  567.483106  783.856123  216.373017        -37.25                  NaN
# 3  479.032348  740.754375  261.722027       -202.63                  NaN
# 4 -558.366690  221.599810  779.966500        351.52                  NaN
#
#    slope_of_regression_5  ma30  sd30  lowbol  upbol
# ...

# %%
# pt(df['buyvol'])

# %%
plt.plot(df['netvol'][:200])
plt.plot(df['close'][:200])
plt.show()

# %%
ndf = pd.read_csv('Binance_BTCUSDT_d.csv')

# %%
ndf.head()
# Out:
#            unix     date    symbol     open     high      low    close  \
# 0  1.652400e+12  44694.0  BTC/USDT  29020.8  29300.0  28730.4  29189.7
# 1  1.652314e+12  44693.0  BTC/USDT  29077.9  30257.0  26631.0  29020.7
# 2  1.652227e+12  44692.0  BTC/USDT  31002.1  32197.6  27651.0  29074.7
# 3  1.652141e+12  44691.0  BTC/USDT  30056.0  32650.0  29701.4  31002.1
# 4  1.652054e+12  44690.0  BTC/USDT  34032.1  34243.3  30003.6  30056.6
#
#    Volume BTC   Volume USDT pct_chagnge  Unnamed: 10
# 0    13070.24  3.791286e+08         NaN          NaN
# 1   964475.59  2.741261e+10         -1%          NaN
# 2  1101875.97  3.343266e+10          0%          NaN
# 3   863178.96  2.700279e+10          7%          NaN
# 4  1078779.71  3.458509e+10         -3%          NaN

# %%
ndf['totalsum'] = np.where
